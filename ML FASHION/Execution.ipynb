# %%
# cell 1
# !python reconstruct.py --model autoencoder_fashion_mnist_dim2.pth --latent_dim 2 --index 10
# Out:
# Menggunakan device: cpu
# Model berhasil dimuat dari: autoencoder_fashion_mnist_dim2.pth (latent_dim=2)
# 100% 26.4M/26.4M [00:01<00:00, 20.2MB/s]
# 100% 29.5k/29.5k [00:00<00:00, 301kB/s]
# 100% 4.42M/4.42M [00:00<00:00, 5.64MB/s]
# 100% 5.15k/5.15k [00:00<00:00, 35.3MB/s]
# Index 10 -> label kelas: 4
# Selesai. File tersimpan: original.png, reconstructed.png, comparison.png

# %%
# cell 2
# !python generate_from_decoder.py --decoder decoder_fashion_mnist_dim2.pth --latent_dim 2 --z1 0.5 --z2 -1.2
# Out:
# Menggunakan device: cpu
# Decoder berhasil dimuat dari: decoder_fashion_mnist_dim2.pth (latent_dim=2)
# Latent vector yang dipakai: [ 0.5 -1.2]
# Selesai. Gambar hasil generate disimpan di: ./generated_image.png
